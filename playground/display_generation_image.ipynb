# %% [markdown]
# ### プロンプト・画像ペアの結果表示
#
# ローカル or SSH先で実行
#
# #### 実行手順
# 1. setup
# 2. 引数を指定して以下を実行
# ```
# img_result = display_result(Args())
# display(img_result)
# ```

# %%
# Setup

# %cd ~/workspace/research/data-juicer/

import sys
sys.path.append("./playground")

from playground.display_generation_image import display_result
from IPython.display import display

class Args:
    def __init__(self, model_name="SD1_5_SP1", image_id="qual_dev_00003.jpg", prompt_path="./DetailMaster_Dataset/DetailMaster_Dataset.json"):
        self.model_name = model_name
        self.image_id = image_id
        self.prompt_path = prompt_path
# Out:
# /home/g2481424/workspace/research/data-juicer

# %%
# !python playground/display_generation_image.py
# Out:
# --------------------------------------------------
# ✅ 画像生成結果の確認 - モデル: SD1_5_ICL1
# 📂 画像ファイルパス: ./evaluation_pipeline/image_generation_example/output_image_SD1_5_ICL1/docci_SD1_5_ICL1_0_qual_dev_00003.jpg
# 🆔 画像ID: qual_dev_00003.jpg
# --------------------------------------------------
# 📝 Polished Prompt:
# ...

# %%
args = Args()
img_result = display_result(args)
display(img_result)
# Out:
# --------------------------------------------------
# ✅ 画像生成結果の確認 - モデル: SD1_5_ICL1
# 📂 画像ファイルパス: ./evaluation_pipeline/image_generation_example/output_image_SD1_5_ICL1/docci_SD1_5_ICL1_0_qual_dev_00003.jpg
# 🆔 画像ID: qual_dev_00003.jpg
# --------------------------------------------------
# 📝 Polished Prompt:
# ...

# %%
args = Args(
  model_name="SD1_5_EM_3",
  # model_name="SD1_5_EM_NP3_3",
  image_id="qual_dev_00008.jpg"
)
img_result = display_result(args)
display(img_result)
# Out:
# --------------------------------------------------
# ✅ 画像生成結果の確認 - モデル: SD1_5_EM_3
# 📂 画像ファイルパス: ./evaluation_pipeline/image_generation_example/output_image_SD1_5_EM_3/docci_SD1_5_EM_3_1_qual_dev_00008.jpg
# 🆔 画像ID: qual_dev_00008.jpg
# --------------------------------------------------
# 📝 Polished Prompt:
# ...
